# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavreddy910/RL_project/blob/main/Proposed_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import tensorflow as tf
from tensorflow import keras
import gym
import matplotlib.pyplot as plt
from matplotlib import style
from  matplotlib import pylab
from google.colab import drive
from skimage.color import rgb2gray
from collections import deque
from keras.models import Sequential
from keras.layers import Conv2D,Dense, Activation, Flatten
from tensorflow.keras.optimizers import Adam
# %matplotlib inline

# %%
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (15,9)
load_model = False

# %%
# %%capture
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unrar e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def preprocess_img(img):
    # Crop and resize the image
    img = img[1:168:2,::2]

    # Convert the image to greyscale
    #img = img.mean(axis=2)
    #img = tf.image.rgb_to_grayscale(img)
    img = rgb2gray(img)

    # reshaping
    img = img.reshape(84,80,1)

    return img

# %%
env = gym.make("MsPacman-v0")
action_size = env.action_space.n
state_size = env.observation_space.shape[0]

print(env.action_space)
print(env.get_action_meanings())
print(env.observation_space)
print("\nAction Size = " + str(action_size))
print("State Size = " + str(state_size) + "\n")

observation = env.reset()

fig, axes = plt.subplots(1, 2, figsize=(8, 8))
ax = axes.ravel()
ax[0].imshow(observation)
ax[0].set_title("Original")
ax[1].imshow(preprocess_img(observation).reshape(84,80), cmap=plt.cm.gray)
#ax[1].imshow(preprocess_img(observation), cmap=plt.cm.gray)
ax[1].set_title("Preprocessed")
plt.show()
# Out:
# Discrete(9)
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']
# Box(0, 255, (210, 160, 3), uint8)
#
# Action Size = 9
# State Size = 210

# %%
num_episodes= 150     

replay_memory_size = 1000  
training_threshold = 200

update_target_every = 3

epsilon_final_episode = 20                
epsilon_min = 0.1     

gamma = 0.99
learning_rate = 0.00015        
batch_size = 32 

load_model = False

# %%
class Agent():
    def __init__(self, epsilon_final_episode, epsilon_min, 
                       gamma, learning_rate, state_size, action_size,
                       batch_size, replay_memory_size,training_threshold):
        '''CREATING AND DEFINING BASIC PARAMETERS FOR TRAINING'''
        # Change epsilon if model is already trained.
        self.epsilon = 1.0                                                                
        self.epsilon_final_episode = epsilon_final_episode 
        self.epsilon_min = epsilon_min                
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.replay_memory_size = replay_memory_size

        self.state_size = state_size
        self.action_size = action_size
        
        self.batch_size = batch_size
        self.training_threshold = training_threshold

         # Main Model
        self.model = self.create_model()
        
         # Target Model
        self.target_model = self.create_model()
        self.target_model.set_weights(self.model.get_weights())
 
        self.target_update_counter = 0

        # Replay Memory
        self.replay_memory = deque(maxlen=self.replay_memory_size) 

        if load_model:
            self.model.load_weights("/content/drive/MyDrive/Colab Notebooks/RL_Project/Checkpoints/weights3.h5")        
        
    def update_replay_memory(self, state, action, reward, next_state, done):
        '''UPDATING REPLAY MEMORY and DECAYING EPSILON'''
        self.replay_memory.append((state, action, reward, next_state, done))

    def update_epsilon(self,episode):
        if episode <= self.epsilon_final_episode:                                                       
            self.epsilon = 1 + ((self.epsilon_min - 1)/self.epsilon_final_episode)*episode   # Linearly annealed  
    

    def create_model(self):
        '''CREATING NEURAL NETWORK'''
        keras.backend.clear_session()
        model = Sequential()
        model.add(Conv2D(16,kernel_size = (4,4),strides = 2,padding='same',activation='relu',input_shape=(84,80,1)))
        model.add(Conv2D(32,kernel_size = (4,4),strides = 2,padding='same',activation='relu'))
        model.add(Conv2D(32,kernel_size = (3,3),strides = 1,padding='same',activation='relu'))
        model.add(Flatten())
        model.add(Dense(512, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.summary()
        model.compile(optimizer=Adam(learning_rate==self.learning_rate), loss = "mse")          
        return model
    

    def select_action(self, state):
        '''DEFINING EPSILON GREEDY STRATEGY'''
        if np.random.rand() > self.epsilon:
            q_value = self.model.predict(state.reshape(1,84,80,1),batch_size=1)
            return np.argmax(q_value[0])
        else:
            return np.random.randint(0, self.action_size)             
 

    def train_agent(self):
        '''TRAINING AGENT'''
        if len(self.replay_memory) < self.training_threshold:
                  return
        
        batch_size = min(self.batch_size, len(self.replay_memory))
        minibatch = random.sample(self.replay_memory, batch_size)
 
        observations = np.zeros((batch_size, 84, 80, 1))                    
        next_observations = np.zeros((batch_size, 84, 80, 1))
        
        action = []
        reward = [] 
        done = []
        
        for sample_index in range(self.batch_size):
            observations[sample_index] = minibatch[sample_index][0]                       
            action.append(minibatch[sample_index][1])
            reward.append(minibatch[sample_index][2])
            next_observations[sample_index] = minibatch[sample_index][3]
            done.append(minibatch[sample_index][4])

            
        current_q_values = self.model.predict(observations)
        future_q_values = self.target_model.predict(next_observations)
    
        for index in range(self.batch_size):
            if not done[index]:    
                current_q_values[index][action[index]] = reward[index] + self.gamma * (np.amax(future_q_values[index]))
            else:
                current_q_values[index][action[index]] = reward[index]            

        self.model.fit(observations, current_q_values, batch_size = batch_size, verbose=0)                              
        
        if done:
            self.target_update_counter += 1
        
        if self.target_update_counter > update_target_every:
            self.target_model.set_weights(self.model.get_weights())
            self.target_update_counter = 0

# %%
agent = Agent(epsilon_final_episode, epsilon_min, 
                  gamma, learning_rate, state_size, 
                  action_size, batch_size, replay_memory_size,training_threshold)

scores = []
eps_plot = []
episodes = []
rewards_lst = []

for episode in range(num_episodes):
    done = False
    score = 0
    frame = 0
    state = env.reset()
    #state = np.reshape(state, [1, 100800])
    state = preprocess_img(state)  
    agent.update_epsilon(episode)                                    
    while not done:
            #env.render()
            action = agent.select_action(state)
                
            next_state, reward, done, info = env.step(action)                      
            #next_state = np.reshape(next_state, [1, 100800])  
            next_state = preprocess_img(next_state)                  
                
            agent.update_replay_memory(state, action, reward, next_state, done)
            agent.train_agent()
                
            state = next_state
            score += reward
            frame += 1
   
    scores.append(score)
    episodes.append(episode)
    print("Episode:", episode, "     Score:", score,"     Epsilon:", agent.epsilon,"     Frames:", frame)

    if (episode % 5 == 0) & (load_model==False):
        agent.model.save_weights("/content/drive/MyDrive/Colab Notebooks/RL_Project/Checkpoints/weights3.h5")
        print("Saved model to disk")
    
    pylab.plot(episodes, scores, 'red', linewidth=2)
    plt.xlabel("Episodes",size=20)
    plt.ylabel("Scores",size=20)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.grid(True,color="gray")
    pylab.savefig("/content/drive/MyDrive/Colab Notebooks/RL_Project/Scores3.png")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 42, 40, 16)        272
#
#  conv2d_1 (Conv2D)           (None, 21, 20, 32)        8224
#
#  conv2d_2 (Conv2D)           (None, 21, 20, 32)        9248
#
#  flatten (Flatten)           (None, 13440)             0
#
#  dense (Dense)               (None, 512)               6881792
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 6,904,153
# Trainable params: 6,904,153
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 42, 40, 16)        272
#
#  conv2d_1 (Conv2D)           (None, 21, 20, 32)        8224
#
#  conv2d_2 (Conv2D)           (None, 21, 20, 32)        9248
#
#  flatten (Flatten)           (None, 13440)             0
#
#  dense (Dense)               (None, 512)               6881792
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 6,904,153
# Trainable params: 6,904,153
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 0      Score: 240.0      Epsilon: 1.0      Frames: 527
# Saved model to disk
# Episode: 1      Score: 300.0      Epsilon: 0.955      Frames: 721
# Episode: 2      Score: 270.0      Epsilon: 0.91      Frames: 643
# Episode: 3      Score: 190.0      Epsilon: 0.865      Frames: 643
# Episode: 4      Score: 270.0      Epsilon: 0.8200000000000001      Frames: 874
# Episode: 5      Score: 200.0      Epsilon: 0.775      Frames: 687
# Saved model to disk
# Episode: 6      Score: 280.0      Epsilon: 0.73      Frames: 728
# Episode: 7      Score: 270.0      Epsilon: 0.685      Frames: 745
# Episode: 8      Score: 370.0      Epsilon: 0.64      Frames: 707
# Episode: 9      Score: 160.0      Epsilon: 0.595      Frames: 645
# Episode: 10      Score: 180.0      Epsilon: 0.55      Frames: 584
# Saved model to disk
# Episode: 11      Score: 290.0      Epsilon: 0.505      Frames: 696
# Episode: 12      Score: 480.0      Epsilon: 0.45999999999999996      Frames: 818
# Episode: 13      Score: 290.0      Epsilon: 0.41500000000000004      Frames: 606
# Episode: 14      Score: 270.0      Epsilon: 0.37      Frames: 557
# Episode: 15      Score: 550.0      Epsilon: 0.32500000000000007      Frames: 845
# Saved model to disk
# Episode: 16      Score: 560.0      Epsilon: 0.28      Frames: 874
# Episode: 17      Score: 130.0      Epsilon: 0.235      Frames: 554
# Episode: 18      Score: 330.0      Epsilon: 0.19000000000000006      Frames: 625
# Episode: 19      Score: 300.0      Epsilon: 0.14500000000000002      Frames: 533
# Episode: 20      Score: 120.0      Epsilon: 0.10000000000000009      Frames: 479
# Saved model to disk
# Episode: 21      Score: 350.0      Epsilon: 0.10000000000000009      Frames: 654
# Episode: 22      Score: 220.0      Epsilon: 0.10000000000000009      Frames: 465
# Episode: 23      Score: 120.0      Epsilon: 0.10000000000000009      Frames: 614
# Episode: 24      Score: 350.0      Epsilon: 0.10000000000000009      Frames: 621
# Episode: 25      Score: 600.0      Epsilon: 0.10000000000000009      Frames: 912
# Saved model to disk
# Episode: 26      Score: 1700.0      Epsilon: 0.10000000000000009      Frames: 742
# Episode: 27      Score: 1110.0      Epsilon: 0.10000000000000009      Frames: 958
# Episode: 28      Score: 600.0      Epsilon: 0.10000000000000009      Frames: 810
# Episode: 29      Score: 680.0      Epsilon: 0.10000000000000009      Frames: 845
# Episode: 30      Score: 250.0      Epsilon: 0.10000000000000009      Frames: 724
# Saved model to disk
# Episode: 31      Score: 200.0      Epsilon: 0.10000000000000009      Frames: 613
# Episode: 32      Score: 310.0      Epsilon: 0.10000000000000009      Frames: 670
# Episode: 33      Score: 630.0      Epsilon: 0.10000000000000009      Frames: 936
# Episode: 34      Score: 260.0      Epsilon: 0.10000000000000009      Frames: 555
# Episode: 35      Score: 170.0      Epsilon: 0.10000000000000009      Frames: 491
# Saved model to disk
# Episode: 36      Score: 220.0      Epsilon: 0.10000000000000009      Frames: 749
# Episode: 37      Score: 330.0      Epsilon: 0.10000000000000009      Frames: 683
# Episode: 38      Score: 410.0      Epsilon: 0.10000000000000009      Frames: 757
# Episode: 39      Score: 360.0      Epsilon: 0.10000000000000009      Frames: 677
# Episode: 40      Score: 410.0      Epsilon: 0.10000000000000009      Frames: 859
# Saved model to disk
# Episode: 41      Score: 340.0      Epsilon: 0.10000000000000009      Frames: 867
# Episode: 42      Score: 430.0      Epsilon: 0.10000000000000009      Frames: 1023
# Episode: 43      Score: 330.0      Epsilon: 0.10000000000000009      Frames: 607
# Episode: 44      Score: 300.0      Epsilon: 0.10000000000000009      Frames: 723
# Episode: 45      Score: 220.0      Epsilon: 0.10000000000000009      Frames: 589
# Saved model to disk
# Episode: 46      Score: 640.0      Epsilon: 0.10000000000000009      Frames: 784
# Episode: 47      Score: 160.0      Epsilon: 0.10000000000000009      Frames: 423
# Episode: 48      Score: 300.0      Epsilon: 0.10000000000000009      Frames: 543
# Episode: 49      Score: 630.0      Epsilon: 0.10000000000000009      Frames: 700
# Episode: 50      Score: 490.0      Epsilon: 0.10000000000000009      Frames: 976
# Saved model to disk
# Episode: 51      Score: 310.0      Epsilon: 0.10000000000000009      Frames: 620
# Episode: 52      Score: 330.0      Epsilon: 0.10000000000000009      Frames: 617
# Episode: 53      Score: 530.0      Epsilon: 0.10000000000000009      Frames: 749
# Episode: 54      Score: 70.0      Epsilon: 0.10000000000000009      Frames: 350
# Episode: 55      Score: 410.0      Epsilon: 0.10000000000000009      Frames: 743
# Saved model to disk
# Episode: 56      Score: 400.0      Epsilon: 0.10000000000000009      Frames: 1271
# Episode: 57      Score: 540.0      Epsilon: 0.10000000000000009      Frames: 1041
# Episode: 58      Score: 750.0      Epsilon: 0.10000000000000009      Frames: 980
# Episode: 59      Score: 290.0      Epsilon: 0.10000000000000009      Frames: 630
# Episode: 60      Score: 370.0      Epsilon: 0.10000000000000009      Frames: 601
# Saved model to disk
# Episode: 61      Score: 860.0      Epsilon: 0.10000000000000009      Frames: 1123
# Episode: 62      Score: 160.0      Epsilon: 0.10000000000000009      Frames: 502
# Episode: 63      Score: 430.0      Epsilon: 0.10000000000000009      Frames: 841
# Episode: 64      Score: 850.0      Epsilon: 0.10000000000000009      Frames: 753
# Episode: 65      Score: 400.0      Epsilon: 0.10000000000000009      Frames: 721
# Saved model to disk
# Episode: 66      Score: 280.0      Epsilon: 0.10000000000000009      Frames: 494
# Episode: 67      Score: 630.0      Epsilon: 0.10000000000000009      Frames: 1010
# Episode: 68      Score: 830.0      Epsilon: 0.10000000000000009      Frames: 1101
# Episode: 69      Score: 280.0      Epsilon: 0.10000000000000009      Frames: 580
# Episode: 70      Score: 670.0      Epsilon: 0.10000000000000009      Frames: 705
# Saved model to disk
# Episode: 71      Score: 380.0      Epsilon: 0.10000000000000009      Frames: 648
# Episode: 72      Score: 430.0      Epsilon: 0.10000000000000009      Frames: 891
# Episode: 73      Score: 340.0      Epsilon: 0.10000000000000009      Frames: 705
# Episode: 74      Score: 280.0      Epsilon: 0.10000000000000009      Frames: 697
# Episode: 75      Score: 340.0      Epsilon: 0.10000000000000009      Frames: 677
# Saved model to disk
# Episode: 76      Score: 530.0      Epsilon: 0.10000000000000009      Frames: 847
# Episode: 77      Score: 300.0      Epsilon: 0.10000000000000009      Frames: 527
# Episode: 78      Score: 450.0      Epsilon: 0.10000000000000009      Frames: 801
# Episode: 79      Score: 310.0      Epsilon: 0.10000000000000009      Frames: 452
# Episode: 80      Score: 300.0      Epsilon: 0.10000000000000009      Frames: 628
# Saved model to disk
# Episode: 81      Score: 370.0      Epsilon: 0.10000000000000009      Frames: 556
# Episode: 82      Score: 1550.0      Epsilon: 0.10000000000000009      Frames: 1203
# Episode: 83      Score: 730.0      Epsilon: 0.10000000000000009      Frames: 966
# Episode: 84      Score: 180.0      Epsilon: 0.10000000000000009      Frames: 505
# Episode: 85      Score: 780.0      Epsilon: 0.10000000000000009      Frames: 1086
# Saved model to disk
# Episode: 86      Score: 500.0      Epsilon: 0.10000000000000009      Frames: 831
# Episode: 87      Score: 460.0      Epsilon: 0.10000000000000009      Frames: 751
# Episode: 88      Score: 340.0      Epsilon: 0.10000000000000009      Frames: 1064
# Episode: 89      Score: 430.0      Epsilon: 0.10000000000000009      Frames: 619
# Episode: 90      Score: 730.0      Epsilon: 0.10000000000000009      Frames: 1025
# Saved model to disk
# Episode: 91      Score: 610.0      Epsilon: 0.10000000000000009      Frames: 1020
# Episode: 92      Score: 450.0      Epsilon: 0.10000000000000009      Frames: 738
# Episode: 93      Score: 230.0      Epsilon: 0.10000000000000009      Frames: 686
# Episode: 94      Score: 330.0      Epsilon: 0.10000000000000009      Frames: 567
# Episode: 95      Score: 250.0      Epsilon: 0.10000000000000009      Frames: 560
# Saved model to disk
# Episode: 96      Score: 280.0      Epsilon: 0.10000000000000009      Frames: 514
# Episode: 97      Score: 350.0      Epsilon: 0.10000000000000009      Frames: 619
# Episode: 98      Score: 360.0      Epsilon: 0.10000000000000009      Frames: 728
# Episode: 99      Score: 280.0      Epsilon: 0.10000000000000009      Frames: 642
# Episode: 100      Score: 240.0      Epsilon: 0.10000000000000009      Frames: 554
# Saved model to disk
# Episode: 101      Score: 870.0      Epsilon: 0.10000000000000009      Frames: 844
# Episode: 102      Score: 160.0      Epsilon: 0.10000000000000009      Frames: 436
# Episode: 103      Score: 320.0      Epsilon: 0.10000000000000009      Frames: 575
# Episode: 104      Score: 330.0      Epsilon: 0.10000000000000009      Frames: 652
# Episode: 105      Score: 1360.0      Epsilon: 0.10000000000000009      Frames: 1079
# Saved model to disk
# Episode: 106      Score: 1360.0      Epsilon: 0.10000000000000009      Frames: 1440
# Episode: 107      Score: 110.0      Epsilon: 0.10000000000000009      Frames: 477
# Episode: 108      Score: 890.0      Epsilon: 0.10000000000000009      Frames: 922
# Episode: 109      Score: 1240.0      Epsilon: 0.10000000000000009      Frames: 1257
# Episode: 110      Score: 290.0      Epsilon: 0.10000000000000009      Frames: 594
# Saved model to disk
# Episode: 111      Score: 300.0      Epsilon: 0.10000000000000009      Frames: 610
# Episode: 112      Score: 1590.0      Epsilon: 0.10000000000000009      Frames: 1127
# Episode: 113      Score: 510.0      Epsilon: 0.10000000000000009      Frames: 686
# Episode: 114      Score: 640.0      Epsilon: 0.10000000000000009      Frames: 676
# Episode: 115      Score: 460.0      Epsilon: 0.10000000000000009      Frames: 688
# Saved model to disk
# Episode: 116      Score: 360.0      Epsilon: 0.10000000000000009      Frames: 702
# Episode: 117      Score: 410.0      Epsilon: 0.10000000000000009      Frames: 715
# Episode: 118      Score: 170.0      Epsilon: 0.10000000000000009      Frames: 443
# Episode: 119      Score: 640.0      Epsilon: 0.10000000000000009      Frames: 753
# Episode: 120      Score: 190.0      Epsilon: 0.10000000000000009      Frames: 557
# Saved model to disk
# Episode: 121      Score: 190.0      Epsilon: 0.10000000000000009      Frames: 648
# Episode: 122      Score: 370.0      Epsilon: 0.10000000000000009      Frames: 686
# Episode: 123      Score: 500.0      Epsilon: 0.10000000000000009      Frames: 942
# Episode: 124      Score: 270.0      Epsilon: 0.10000000000000009      Frames: 554
# Episode: 125      Score: 790.0      Epsilon: 0.10000000000000009      Frames: 791
# Saved model to disk
# Episode: 126      Score: 600.0      Epsilon: 0.10000000000000009      Frames: 796
# Episode: 127      Score: 200.0      Epsilon: 0.10000000000000009      Frames: 649
# Episode: 128      Score: 270.0      Epsilon: 0.10000000000000009      Frames: 533
# Episode: 129      Score: 320.0      Epsilon: 0.10000000000000009      Frames: 608
# Episode: 130      Score: 690.0      Epsilon: 0.10000000000000009      Frames: 848
# Saved model to disk
# Episode: 131      Score: 350.0      Epsilon: 0.10000000000000009      Frames: 570
# Episode: 132      Score: 390.0      Epsilon: 0.10000000000000009      Frames: 750
# Episode: 133      Score: 710.0      Epsilon: 0.10000000000000009      Frames: 991
# Episode: 134      Score: 580.0      Epsilon: 0.10000000000000009      Frames: 864
# Episode: 135      Score: 1700.0      Epsilon: 0.10000000000000009      Frames: 1303
# Saved model to disk
# Episode: 136      Score: 160.0      Epsilon: 0.10000000000000009      Frames: 583
# Episode: 137      Score: 360.0      Epsilon: 0.10000000000000009      Frames: 726
# Episode: 138      Score: 230.0      Epsilon: 0.10000000000000009      Frames: 519
# Episode: 139      Score: 540.0      Epsilon: 0.10000000000000009      Frames: 1076
# Episode: 140      Score: 250.0      Epsilon: 0.10000000000000009      Frames: 592
# Saved model to disk
# Episode: 141      Score: 440.0      Epsilon: 0.10000000000000009      Frames: 603
# Episode: 142      Score: 320.0      Epsilon: 0.10000000000000009      Frames: 549
# Episode: 143      Score: 350.0      Epsilon: 0.10000000000000009      Frames: 587
# Episode: 144      Score: 730.0      Epsilon: 0.10000000000000009      Frames: 838
# Episode: 145      Score: 640.0      Epsilon: 0.10000000000000009      Frames: 818
# Saved model to disk
# Episode: 146      Score: 430.0      Epsilon: 0.10000000000000009      Frames: 687
# Episode: 147      Score: 810.0      Epsilon: 0.10000000000000009      Frames: 760
# Episode: 148      Score: 290.0      Epsilon: 0.10000000000000009      Frames: 526

# %% [markdown]
# ![Scores3 (2).png](data:image/png;base64,...)
